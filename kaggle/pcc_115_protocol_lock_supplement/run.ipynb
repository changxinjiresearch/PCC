# %%
from pathlib import Path
import subprocess, sys
repo=Path('/tmp/PCC')
subprocess.run(['git','clone','--quiet','https://github.com/changxinjiresearch/PCC.git',str(repo)],check=True)
subprocess.run(['git','-C',str(repo),'checkout','--quiet','310c2763316ff3d785eaa01a33891e93b202b877'],check=True)
out=Path('/kaggle/working/pcc_115_protocol_lock_supplement_2026')
subprocess.run([sys.executable,'-m','experiments.pcc_115_protocol_supplement_cpu_audit','--input-root','/kaggle/input','--output-root',str(out),'--repo',str(repo)],cwd=repo,check=True)
