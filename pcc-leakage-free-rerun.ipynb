# %% [markdown]
# # PCC_LEAKAGE_FREE_RERUN_2026
# Canonical one-fold/one-case smoke entry. Run the full command only after smoke artifacts validate.

# %%
import subprocess, sys
subprocess.run([sys.executable, 'experiments/run_pcc_leakage_free_full.py', '--config', 'configs/pcc_leakage_free_canonical.yaml', '--smoke'], check=True)
